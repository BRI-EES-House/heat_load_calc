# %%
from matplotlib import pyplot as plt
import heat_load_calc.iso7730 as original
from heat_load_calc.core import occupants

# %% [markdown]
# オリジナルのPMV計算と今回の計算との比較

# %%
original.get_pmv_ppd(met_value=1.0, p_eff=0.0, t_a=22.0, t_r_bar=22.0, clo_value=0.5, v_ar=0.1, rh=60.0)
# Out:
# (-1.445437013135129, 47.947211862682465)

# %%
xs = [x * 0.1 for x in range(0, 10, 1)]
ys = [occupants.get_h_hum_c_is_n(theta_r_is_n=28.0, theta_cl_is_n=35.0, v_hum_is_n=x) for x in xs]
plt.scatter(xs, ys)
plt.xlabel('velocity, m/s')
plt.ylabel('convective heat transfer coefficient, W/m2K')
plt.show()

# %%
xs = [x * 0.1 for x in range(0, 200)]
ys = [2.38 * x ** 0.25 for x in xs]
plt.scatter(xs, ys)
plt.xlabel('temperature dif. between clothing and air, deg. C')
plt.ylabel('convective heat transfer coefficient (laminar flow), W/m2K')
plt.show()
